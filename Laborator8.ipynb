# %% [markdown]
# # Laborator 8

# %% [markdown]
# ## Modele de regresie
#
# Folositi urmatoarele seturi de date:
# 1. [CPU Computer Hardware](https://archive.ics.uci.edu/ml/datasets/Computer+Hardware); excludeti din dataset coloanele: vendor name, model name, estimated relative performance; se va estima coloana "published relative performance".
# 1. [Boston Housing](http://archive.ics.uci.edu/ml/machine-learning-databases/housing/)
# 1. [Wisconsin Breast Cancer](http://www.dcc.fc.up.pt/~ltorgo/Regression/DataSets.html); cautati in panelul din stanga Wisconsin Breast Cancer si urmati pasii din "My personal Notes"
# 1. [Communities and Crime](http://archive.ics.uci.edu/ml/datasets/communities+and+crime); stergeti primele 5 dimensiuni si trasaturile cu missing values.
#
# Pentru fiecare set de date aplicati minim 5 modele de regresie din scikit learn. Pentru fiecare raportati: mean absolute error, mean squared error, median absolute error - a se vedea [sklearn.metrics](http://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) - folosind 5 fold cross validation. Valorile hiperparametrilor trebuie cautate cu grid search (cv=3)  si random search (n_iter dat de voi). Metrica folosita pentru cautarea hiperparametrilor va fi mean squared error. Raportati mediile rezultatelor atat pentru fold-urile de antrenare, cat si pentru cele de testare; indicatie: puteti folosi metoda `cross_validate` cu parametrul `return_train_score=True`, iar ca model un obiect de tip `GridSearchCV` sau `RandomizedSearchCV`.
#
# Rezultatele vor fi trecute intr-un dataframe. Intr-o stare intermediara, valorile vor fi calculate cu semnul minus: din motive de implementare, biblioteca sklearn transforma scorurile in numere negative; a se vedea imaginea de mai jos:
#
# ![intermediate report](./images/cpu_intermediate_blurred.png)
#
#
# Valorile vor fi aduse la interval pozitiv, apoi vor fi marcate cele maxime si minime; orientativ, se poate folosi imaginea de mai jos, reprezentand dataframe afisat in notebook; puteti folosi alte variante de styling pe dataframe precum la https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#.
#
# Se va crea un raport final in format HTML sau PDF - fisier(e) separat(e). Raportul trebuie sa contina minimal: numele setului de date si obiectul dataframe; preferabil sa se pastreze marcajul de culori realizat in notebook.
#
# ![report](./images/cpu_results_blurred.png)
#
# Notare:
# 1. Se acorda 20 de puncte din oficiu.
# 1. Optimizare si cuantificare de performanta a modelelor: 3 puncte pentru fiecare combinatie set de date + model = 60 de puncte
# 1. Documentare modele: numar modele * 2 puncte = 10 puncte. Documentati in jupyter notebook fiecare din modelele folosite, in limba romana. Puteti face o sectiune separata cu documentarea algoritmilor. Fiecare model trebuie sa aiba o descriere de minim 20 de randuri, minim o imagine asociata si minim 2 referinte bibliografice.
# 1. 10 puncte: export in format HTML sau PDF.

# %% [markdown]
# *Notare:* laboratorul va fi salvat in repository-ul de github si prezentat in saptamana 6-10 mai.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_validate
from sklearn import linear_model
from scipy.stats import uniform as sp_rand
from sklearn import ensemble
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
data_cpu = pd.read_csv('machine.data', header=None)
data_cpu=data_cpu.values[:,2:-1]
x_cpu=data_cpu[:, :-1]
y_cpu=data_cpu[:, -1]

boston_housing = pd.read_csv('housing.data', header=None, delim_whitespace=True)
x_housing = boston_housing.values[:, :-1]
y_housing = boston_housing.values[:, -1]

wisconsin_breast_cancer = pd.read_csv('r_wpbc.data', header=None)
x_wisconsin = wisconsin_breast_cancer.values[:, :-1]
y_wisconsin = wisconsin_breast_cancer.values[:, -1]

communities_and_crime = pd.read_csv('communities.data', header=None)
communities_and_crime = communities_and_crime[(communities_and_crime != '?').all(axis=1)]
x_communities = communities_and_crime.values[:,5:-1]
y_communities = communities_and_crime.values[:,-1]

# %%
def fun(x,y, model):
    warnings.simplefilter(action='ignore')
    alphas = {'alpha' : [0.1, 1.0, 10.0]}
    grid = GridSearchCV(model, param_grid=alphas, cv=3,scoring='neg_mean_squared_error')
    grid= cross_validate(grid,x, y,scoring=('neg_mean_absolute_error','neg_mean_squared_error','neg_median_absolute_error'),
                             cv=5, return_train_score=True)

    GridSearch={'test_mean_absolute_error':abs(grid['test_neg_mean_absolute_error'].mean()),
                'test_mean_squared_error':abs(grid['test_neg_mean_squared_error'].mean()),
                'test_median_absolute_error':abs(grid['test_neg_median_absolute_error'].mean()),
                'train_mean_absolute_error':abs(grid['train_neg_mean_absolute_error'].mean()),
                'train_mean_squared_error':abs(grid['train_neg_mean_squared_error'].mean()),
                'train_median_absolute_error':abs(grid['train_neg_median_absolute_error'].mean())}




    rsearch = RandomizedSearchCV(estimator=model, param_distributions=alphas, n_iter=3)
    rsearch= cross_validate(rsearch,x, y,scoring=('neg_mean_absolute_error','neg_mean_squared_error','neg_median_absolute_error'),
                             cv=5, return_train_score=True)
    
    RandomSearch={'test_mean_absolute_error': abs(rsearch['test_neg_mean_absolute_error'].mean()),
                'test_mean_squared_error': abs(rsearch['test_neg_mean_squared_error'].mean()),
                'test_median_absolute_error':abs(rsearch['test_neg_median_absolute_error'].mean()),
                'train_mean_absolute_error':abs(rsearch['train_neg_mean_absolute_error'].mean()),
                'train_mean_squared_error':abs(rsearch['train_neg_mean_squared_error'].mean()),
                'train_median_absolute_error':abs(rsearch['train_neg_median_absolute_error'].mean())}
    
    dataset = pd.DataFrame({'GridSearchCV' :GridSearch, 'RandomizedSearchCV': RandomSearch})
    return dataset.T

# %%
def neighReg(x,y):
    params = {'n_neighbors':[5,6,7,8],'leaf_size':[1,2,3],'weights':['uniform', 'distance']}
    
    grid = GridSearchCV(KNeighborsRegressor(), param_grid=params, cv=3, n_jobs= -1, iid=False)

    grid= cross_validate(grid,x, y,scoring=('neg_mean_absolute_error','neg_mean_squared_error','neg_median_absolute_error'),
                             cv=5, return_train_score=True)

    GridSearch={'test_mean_absolute_error':abs(grid['test_neg_mean_absolute_error'].mean()),
                'test_mean_squared_error':abs(grid['test_neg_mean_squared_error'].mean()),
                'test_median_absolute_error':abs(grid['test_neg_median_absolute_error'].mean()),
                'train_mean_absolute_error':abs(grid['train_neg_mean_absolute_error'].mean()),
                'train_mean_squared_error':abs(grid['train_neg_mean_squared_error'].mean()),
                'train_median_absolute_error':abs(grid['train_neg_median_absolute_error'].mean())}




    rsearch = RandomizedSearchCV(estimator=KNeighborsRegressor(), param_distributions=params, n_iter=20)
    rsearch= cross_validate(rsearch,x, y,scoring=('neg_mean_absolute_error','neg_mean_squared_error','neg_median_absolute_error'),
                             cv=5, return_train_score=True)
    
    RandomSearch={'test_mean_absolute_error': abs(rsearch['test_neg_mean_absolute_error'].mean()),
                'test_mean_squared_error': abs(rsearch['test_neg_mean_squared_error'].mean()),
                'test_median_absolute_error':abs(rsearch['test_neg_median_absolute_error'].mean()),
                'train_mean_absolute_error':abs(rsearch['train_neg_mean_absolute_error'].mean()),
                'train_mean_squared_error':abs(rsearch['train_neg_mean_squared_error'].mean()),
                'train_median_absolute_error':abs(rsearch['train_neg_median_absolute_error'].mean())}
    
    dataset = pd.DataFrame({'GridSearchCV' :GridSearch, 'RandomizedSearchCV': RandomSearch})
    return dataset.T

# %%
data_cpu1=fun(x_cpu, y_cpu, linear_model.Ridge())
data_cpu2=fun(x_cpu, y_cpu, linear_model.Lasso())
data_cpu3=fun(x_cpu, y_cpu, linear_model.ElasticNet())
data_cpu4=fun(x_cpu, y_cpu, linear_model.LassoLars())
data_cpu5=neighReg(x_cpu, y_cpu)

data_cpu4
# Out:
#                     test_mean_absolute_error  test_mean_squared_error  \
# GridSearchCV                       41.288543              6201.732604
# RandomizedSearchCV                 39.688969              6938.306195
#
#                     test_median_absolute_error  train_mean_absolute_error  \
# GridSearchCV                         25.326891                  35.639909
# RandomizedSearchCV                   22.917932                  35.171268
#
#                     train_mean_squared_error  train_median_absolute_error
# GridSearchCV                     3427.445058                    23.082545
# RandomizedSearchCV               3650.149457                    21.517765

# %%
boston_housing1 = fun(x_housing, y_housing, linear_model.Ridge())
boston_housing2 = fun(x_housing, y_housing, linear_model.Lasso())
boston_housing3 = fun(x_housing, y_housing, linear_model.ElasticNet())
boston_housing4 = fun(x_housing, y_housing, linear_model.LassoLars())
boston_housing5 = neighReg(x_housing, y_housing)

boston_housing4
# Out:
#                     test_mean_absolute_error  test_mean_squared_error  \
# GridSearchCV                        4.732101                47.578549
# RandomizedSearchCV                  4.732101                47.578549
#
#                     test_median_absolute_error  train_mean_absolute_error  \
# GridSearchCV                          3.236772                   3.991472
# RandomizedSearchCV                    3.236772                   3.991472
#
#                     train_mean_squared_error  train_median_absolute_error
# GridSearchCV                       32.854899                      2.84821
# RandomizedSearchCV                 32.854899                      2.84821

# %%
wisconsin_breast_cancer1 = fun(x_wisconsin, y_wisconsin, linear_model.Ridge())
wisconsin_breast_cancer2 = fun(x_wisconsin, y_wisconsin, linear_model.Lasso())
wisconsin_breast_cancer3 = fun(x_wisconsin, y_wisconsin, linear_model.ElasticNet())
wisconsin_breast_cancer4 = fun(x_wisconsin, y_wisconsin, linear_model.LassoLars())
wisconsin_breast_cancer5 = neighReg(x_wisconsin, y_wisconsin)

wisconsin_breast_cancer4
# Out:
#                     test_mean_absolute_error  test_mean_squared_error  \
# GridSearchCV                       30.665849              1380.216616
# RandomizedSearchCV                 30.665849              1380.216616
#
#                     test_median_absolute_error  train_mean_absolute_error  \
# GridSearchCV                         27.050985                  24.789832
# RandomizedSearchCV                   27.050985                  24.789832
#
#                     train_mean_squared_error  train_median_absolute_error
# GridSearchCV                      890.256356                    22.761165
# RandomizedSearchCV                890.256356                    22.761165

# %%
communities_and_crime1 = fun(x_communities, y_communities, linear_model.Ridge())
communities_and_crime2 = fun(x_communities, y_communities, linear_model.Lasso())
communities_and_crime3 = fun(x_communities, y_communities, linear_model.ElasticNet())
communities_and_crime4 = fun(x_communities, y_communities, linear_model.LassoLars())
communities_and_crime5 = neighReg(x_communities, y_communities)

communities_and_crime4
# Out:
#                     test_mean_absolute_error  test_mean_squared_error  \
# GridSearchCV                        0.228038                 0.074914
# RandomizedSearchCV                  0.228038                 0.074914
#
#                     test_median_absolute_error  train_mean_absolute_error  \
# GridSearchCV                            0.2072                   0.225506
# RandomizedSearchCV                      0.2072                   0.225506
#
#                     train_mean_squared_error  train_median_absolute_error
# GridSearchCV                        0.073671                     0.206605
# RandomizedSearchCV                  0.073671                     0.206605

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_min = s == s.max()
    return ['background-color: red' if v else '' for v in is_min]

def highlight_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_min = s == s.min()
    return ['background-color: lime' if v else '' for v in is_min]

# data_cpu4_styled=data_cpu4.reset_index(drop=True).style.apply(highlight_max)
# data_cpu4_styled=data_cpu4_styled.apply(highlight_min)
# data_cpu4_styled

# %%
temp = {'Ridge': data_cpu1, 'Lasso': data_cpu2, 'ElasticNet':data_cpu3, 'LassoLars': data_cpu4, 'KNeighborsRegressor':data_cpu5}
result=pd.concat(temp)
result = result.style.apply(highlight_max).apply(highlight_min)
result
# Out:
# <style  type="text/css" >
#     #T_453a9758_7169_11e9_a125_38d5473acabarow1_col3 {
#             background-color:  red;
#             : ;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow1_col5 {
#             background-color:  red;
#             : ;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow2_col2 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow2_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow2_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow2_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow3_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow3_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow3_col2 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow3_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow3_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow3_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow4_col2 {
#             background-color:  red;
#             : ;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow7_col1 {
#             background-color:  red;
#             : ;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow7_col4 {
#             background-color:  red;
#             : ;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow8_col0 {
#             background-color:  red;
#             : ;
#         }    #T_453a9758_7169_11e9_a125_38d5473acabarow9_col0 {
#             background-color:  red;
#             : ;
#         }</style>
# <table id="T_453a9758_7169_11e9_a125_38d5473acaba" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >test_mean_absolute_error</th>
#         <th class="col_heading level0 col1" >test_mean_squared_error</th>
#         <th class="col_heading level0 col2" >test_median_absolute_error</th>
#         <th class="col_heading level0 col3" >train_mean_absolute_error</th>
#         <th class="col_heading level0 col4" >train_mean_squared_error</th>
#         <th class="col_heading level0 col5" >train_median_absolute_error</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel0_row0" class="row_heading level0 row0" rowspan=2>ElasticNet</th>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel1_row0" class="row_heading level1 row0" >GridSearchCV</th>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow0_col0" class="data row0 col0" >42.8733</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow0_col1" class="data row0 col1" >6283.87</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow0_col2" class="data row0 col2" >26.9732</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow0_col3" class="data row0 col3" >36.6645</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow0_col4" class="data row0 col4" >3246.64</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow0_col5" class="data row0 col5" >25.6171</td>
#     </tr>    <tr>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel1_row1" class="row_heading level1 row1" >RandomizedSearchCV</th>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow1_col0" class="data row1 col0" >41.9891</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow1_col1" class="data row1 col1" >6163.51</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow1_col2" class="data row1 col2" >26.4718</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow1_col3" class="data row1 col3" >36.6962</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow1_col4" class="data row1 col4" >3253.22</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow1_col5" class="data row1 col5" >25.7435</td>
#     </tr>    <tr>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel0_row2" class="row_heading level0 row2" rowspan=2>KNeighborsRegressor</th>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel1_row2" class="row_heading level1 row2" >GridSearchCV</th>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow2_col0" class="data row2 col0" >37.0517</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow2_col1" class="data row2 col1" >5869.26</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow2_col2" class="data row2 col2" >17.4342</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow2_col3" class="data row2 col3" >2.56936</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow2_col4" class="data row2 col4" >98.8612</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel1_row3" class="row_heading level1 row3" >RandomizedSearchCV</th>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow3_col0" class="data row3 col0" >36.9836</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow3_col1" class="data row3 col1" >5859.01</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow3_col2" class="data row3 col2" >17.4342</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow3_col3" class="data row3 col3" >2.56936</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow3_col4" class="data row3 col4" >98.8612</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow3_col5" class="data row3 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel0_row4" class="row_heading level0 row4" rowspan=2>Lasso</th>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel1_row4" class="row_heading level1 row4" >GridSearchCV</th>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow4_col0" class="data row4 col0" >43.106</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow4_col1" class="data row4 col1" >6325.13</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow4_col2" class="data row4 col2" >27.0848</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow4_col3" class="data row4 col3" >36.682</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow4_col4" class="data row4 col4" >3247.74</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow4_col5" class="data row4 col5" >25.39</td>
#     </tr>    <tr>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel1_row5" class="row_heading level1 row5" >RandomizedSearchCV</th>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow5_col0" class="data row5 col0" >42.1844</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow5_col1" class="data row5 col1" >6225.74</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow5_col2" class="data row5 col2" >26.5591</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow5_col3" class="data row5 col3" >36.6927</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow5_col4" class="data row5 col4" >3250.29</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow5_col5" class="data row5 col5" >25.4126</td>
#     </tr>    <tr>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel0_row6" class="row_heading level0 row6" rowspan=2>LassoLars</th>
#         <th id="T_453a9758_7169_11e9_a125_38d5473acabalevel1_row6" class="row_heading level1 row6" >GridSearchCV</th>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow6_col0" class="data row6 col0" >41.2885</td>
#         <td id="T_453a9758_7169_11e9_a125_38d5473acabarow6_col1" class=

# %%
temp = {'Ridge': boston_housing1, 'Lasso': boston_housing2, 'ElasticNet':boston_housing3, 'LassoLars': boston_housing4, 'KNeighborsRegressor':boston_housing5}
result=pd.concat(temp)
result = result.style.apply(highlight_max).apply(highlight_min)
result
# Out:
# <style  type="text/css" >
#     #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col0 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col1 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col2 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col0 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col1 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col2 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow6_col3 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow6_col4 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow6_col5 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow7_col3 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow7_col4 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow7_col5 {
#             background-color:  red;
#             : ;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow8_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow8_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow8_col2 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow9_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow9_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow9_col2 {
#             : ;
#             background-color:  lime;
#         }</style>
# <table id="T_50ffa1c2_716a_11e9_9a4d_38d5473acaba" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >test_mean_absolute_error</th>
#         <th class="col_heading level0 col1" >test_mean_squared_error</th>
#         <th class="col_heading level0 col2" >test_median_absolute_error</th>
#         <th class="col_heading level0 col3" >train_mean_absolute_error</th>
#         <th class="col_heading level0 col4" >train_mean_squared_error</th>
#         <th class="col_heading level0 col5" >train_median_absolute_error</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel0_row0" class="row_heading level0 row0" rowspan=2>ElasticNet</th>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel1_row0" class="row_heading level1 row0" >GridSearchCV</th>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow0_col0" class="data row0 col0" >4.64347</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow0_col1" class="data row0 col1" >44.6821</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow0_col2" class="data row0 col2" >3.38535</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow0_col3" class="data row0 col3" >3.65734</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow0_col4" class="data row0 col4" >28.3983</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow0_col5" class="data row0 col5" >2.65765</td>
#     </tr>    <tr>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel1_row1" class="row_heading level1 row1" >RandomizedSearchCV</th>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow1_col0" class="data row1 col0" >4.71406</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow1_col1" class="data row1 col1" >47.1673</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow1_col2" class="data row1 col2" >3.48167</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow1_col3" class="data row1 col3" >3.81266</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow1_col4" class="data row1 col4" >30.8555</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow1_col5" class="data row1 col5" >2.78885</td>
#     </tr>    <tr>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel0_row2" class="row_heading level0 row2" rowspan=2>KNeighborsRegressor</th>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel1_row2" class="row_heading level1 row2" >GridSearchCV</th>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col0" class="data row2 col0" >6.10634</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col1" class="data row2 col1" >77.524</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col2" class="data row2 col2" >4.2765</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col3" class="data row2 col3" >0.809298</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col4" class="data row2 col4" >6.50452</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow2_col5" class="data row2 col5" >0.571429</td>
#     </tr>    <tr>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel1_row3" class="row_heading level1 row3" >RandomizedSearchCV</th>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col0" class="data row3 col0" >6.10634</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col1" class="data row3 col1" >77.524</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col2" class="data row3 col2" >4.2765</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col3" class="data row3 col3" >0.809298</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col4" class="data row3 col4" >6.50452</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow3_col5" class="data row3 col5" >0.571429</td>
#     </tr>    <tr>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel0_row4" class="row_heading level0 row4" rowspan=2>Lasso</th>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel1_row4" class="row_heading level1 row4" >GridSearchCV</th>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow4_col0" class="data row4 col0" >4.5842</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow4_col1" class="data row4 col1" >42.6132</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow4_col2" class="data row4 col2" >3.44623</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow4_col3" class="data row4 col3" >3.6139</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow4_col4" class="data row4 col4" >27.5848</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow4_col5" class="data row4 col5" >2.61156</td>
#     </tr>    <tr>
#         <th id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabalevel1_row5" class="row_heading level1 row5" >RandomizedSearchCV</th>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow5_col0" class="data row5 col0" >4.62523</td>
#         <td id="T_50ffa1c2_716a_11e9_9a4d_38d5473acabarow5_col1" class="data row5 col1" >45.226</td>
#         <td id="T_50ff

# %%
temp = {'Ridge': wisconsin_breast_cancer1, 'Lasso': wisconsin_breast_cancer2, 'ElasticNet':wisconsin_breast_cancer3, 'LassoLars': wisconsin_breast_cancer4, 'KNeighborsRegressor':wisconsin_breast_cancer5}
result=pd.concat(temp)
result = result.style.apply(highlight_max).apply(highlight_min)
result
# Out:
# <style  type="text/css" >
#     #T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col0 {
#             background-color:  red;
#             : ;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col1 {
#             background-color:  red;
#             : ;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col0 {
#             background-color:  red;
#             : ;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col1 {
#             background-color:  red;
#             : ;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col3 {
#             background-color:  red;
#             : ;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col4 {
#             background-color:  red;
#             : ;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow5_col5 {
#             background-color:  red;
#             : ;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow6_col2 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow7_col2 {
#             : ;
#             background-color:  lime;
#         }    #T_5394f7b8_716a_11e9_9b12_38d5473acabarow9_col2 {
#             background-color:  red;
#             : ;
#         }</style>
# <table id="T_5394f7b8_716a_11e9_9b12_38d5473acaba" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >test_mean_absolute_error</th>
#         <th class="col_heading level0 col1" >test_mean_squared_error</th>
#         <th class="col_heading level0 col2" >test_median_absolute_error</th>
#         <th class="col_heading level0 col3" >train_mean_absolute_error</th>
#         <th class="col_heading level0 col4" >train_mean_squared_error</th>
#         <th class="col_heading level0 col5" >train_median_absolute_error</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel0_row0" class="row_heading level0 row0" rowspan=2>ElasticNet</th>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel1_row0" class="row_heading level1 row0" >GridSearchCV</th>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col0" class="data row0 col0" >28.9634</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col1" class="data row0 col1" >1195.9</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col2" class="data row0 col2" >28.3229</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col3" class="data row0 col3" >25.2972</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col4" class="data row0 col4" >924.01</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow0_col5" class="data row0 col5" >22.7917</td>
#     </tr>    <tr>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel1_row1" class="row_heading level1 row1" >RandomizedSearchCV</th>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col0" class="data row1 col0" >28.9634</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col1" class="data row1 col1" >1195.9</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col2" class="data row1 col2" >28.3229</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col3" class="data row1 col3" >25.2972</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col4" class="data row1 col4" >924.01</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow1_col5" class="data row1 col5" >22.7917</td>
#     </tr>    <tr>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel0_row2" class="row_heading level0 row2" rowspan=2>KNeighborsRegressor</th>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel1_row2" class="row_heading level1 row2" >GridSearchCV</th>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col0" class="data row2 col0" >32.5522</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col1" class="data row2 col1" >1471.52</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col2" class="data row2 col2" >29.5636</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col3" class="data row2 col3" >14.1885</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col4" class="data row2 col4" >494.442</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow2_col5" class="data row2 col5" >12.644</td>
#     </tr>    <tr>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel1_row3" class="row_heading level1 row3" >RandomizedSearchCV</th>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col0" class="data row3 col0" >32.5522</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col1" class="data row3 col1" >1471.52</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col2" class="data row3 col2" >29.5636</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col3" class="data row3 col3" >14.1885</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col4" class="data row3 col4" >494.442</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow3_col5" class="data row3 col5" >12.644</td>
#     </tr>    <tr>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel0_row4" class="row_heading level0 row4" rowspan=2>Lasso</th>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel1_row4" class="row_heading level1 row4" >GridSearchCV</th>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col0" class="data row4 col0" >29.055</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col1" class="data row4 col1" >1200.79</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col2" class="data row4 col2" >27.7152</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col3" class="data row4 col3" >25.4075</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col4" class="data row4 col4" >929.394</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow4_col5" class="data row4 col5" >22.9978</td>
#     </tr>    <tr>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel1_row5" class="row_heading level1 row5" >RandomizedSearchCV</th>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow5_col0" class="data row5 col0" >29.1133</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow5_col1" class="data row5 col1" >1207.44</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow5_col2" class="data row5 col2" >27.7749</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow5_col3" class="data row5 col3" >25.3379</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow5_col4" class="data row5 col4" >927.049</td>
#         <td id="T_5394f7b8_716a_11e9_9b12_38d5473acabarow5_col5" class="data row5 col5" >23.0213</td>
#     </tr>    <tr>
#         <th id="T_5394f7b8_716a_11e9_9b12_38d5473acabalevel

# %%
temp = {'Ridge': communities_and_crime1, 'Lasso': communities_and_crime2, 'ElasticNet':communities_and_crime3, 'LassoLars': communities_and_crime4, 'KNeighborsRegressor':communities_and_crime5}
result=pd.concat(temp)
result = result.style.apply(highlight_max).apply(highlight_min)
result
# Out:
# <style  type="text/css" >
#     #T_55e16812_716a_11e9_be36_38d5473acabarow2_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow2_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow2_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow3_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow3_col4 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow3_col5 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow4_col0 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow4_col1 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow4_col2 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow4_col3 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow4_col4 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow4_col5 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow5_col0 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow5_col1 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow5_col2 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow5_col3 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow5_col4 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow5_col5 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow6_col0 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow6_col1 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow6_col2 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow6_col3 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow6_col4 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow6_col5 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow7_col0 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow7_col1 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow7_col2 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow7_col3 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow7_col4 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow7_col5 {
#             background-color:  red;
#             : ;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow8_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow8_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow8_col2 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow9_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow9_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_55e16812_716a_11e9_be36_38d5473acabarow9_col2 {
#             : ;
#             background-color:  lime;
#         }</style>
# <table id="T_55e16812_716a_11e9_be36_38d5473acaba" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >test_mean_absolute_error</th>
#         <th class="col_heading level0 col1" >test_mean_squared_error</th>
#         <th class="col_heading level0 col2" >test_median_absolute_error</th>
#         <th class="col_heading level0 col3" >train_mean_absolute_error</th>
#         <th class="col_heading level0 col4" >train_mean_squared_error</th>
#         <th class="col_heading level0 col5" >train_median_absolute_error</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_55e16812_716a_11e9_be36_38d5473acabalevel0_row0" class="row_heading level0 row0" rowspan=2>ElasticNet</th>
#         <th id="T_55e16812_716a_11e9_be36_38d5473acabalevel1_row0" class="row_heading level1 row0" >GridSearchCV</th>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow0_col0" class="data row0 col0" >0.197273</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow0_col1" class="data row0 col1" >0.0564097</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow0_col2" class="data row0 col2" >0.173538</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow0_col3" class="data row0 col3" >0.193331</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow0_col4" class="data row0 col4" >0.054131</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow0_col5" class="data row0 col5" >0.170149</td>
#     </tr>    <tr>
#         <th id="T_55e16812_716a_11e9_be36_38d5473acabalevel1_row1" class="row_heading level1 row1" >RandomizedSearchCV</th>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow1_col0" class="data row1 col0" >0.197273</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow1_col1" class="data row1 col1" >0.0564097</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow1_col2" class="data row1 col2" >0.173538</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow1_col3" class="data row1 col3" >0.193331</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow1_col4" class="data row1 col4" >0.054131</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow1_col5" class="data row1 col5" >0.170149</td>
#     </tr>    <tr>
#         <th id="T_55e16812_716a_11e9_be36_38d5473acabalevel0_row2" class="row_heading level0 row2" rowspan=2>KNeighborsRegressor</th>
#         <th id="T_55e16812_716a_11e9_be36_38d5473acabalevel1_row2" class="row_heading level1 row2" >GridSearchCV</th>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow2_col0" class="data row2 col0" >0.117179</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow2_col1" class="data row2 col1" >0.0233241</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow2_col2" class="data row2 col2" >0.0894509</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow2_col3" class="data row2 col3" >0</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow2_col4" class="data row2 col4" >0</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_55e16812_716a_11e9_be36_38d5473acabalevel1_row3" class="row_heading level1 row3" >RandomizedSearchCV</th>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow3_col0" class="data row3 col0" >0.117179</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow3_col1" class="data row3 col1" >0.0233241</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow3_col2" class="data row3 col2" >0.0894509</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow3_col3" class="data row3 col3" >0</td>
#         <td id="T_55e16812_716a_11e9_be36_38d5473acabarow3_c

# %%
data_cpu1=data_cpu1.append(data_cpu2)
data_cpu1=data_cpu1.append(data_cpu3)
data_cpu1=data_cpu1.append(data_cpu4)
data_cpu1=data_cpu1.append(data_cpu5)

data_cpu1.to_html('cpu.html')

# %%
boston_housing1 = boston_housing1.append(boston_housing2)
boston_housing1 = boston_housing1.append(boston_housing3)
boston_housing1 = boston_housing1.append(boston_housing4)
boston_housing1 = boston_housing1.append(boston_housing5)

boston_housing1.to_html('housing.html')

wisconsin_breast_cancer1 = wisconsin_breast_cancer1.append(wisconsin_breast_cancer2)
wisconsin_breast_cancer1 = wisconsin_breast_cancer1.append(wisconsin_breast_cancer3)
wisconsin_breast_cancer1 = wisconsin_breast_cancer1.append(wisconsin_breast_cancer4)
wisconsin_breast_cancer1 = wisconsin_breast_cancer1.append(wisconsin_breast_cancer5)

wisconsin_breast_cancer1.to_html('cancer.html')

communities_and_crime1 = communities_and_crime1.append(communities_and_crime2)
communities_and_crime1 = communities_and_crime1.append(communities_and_crime3)
communities_and_crime1 = communities_and_crime1.append(communities_and_crime4)
communities_and_crime1 = communities_and_crime1.append(communities_and_crime5)

communities_and_crime1.to_html('crime.html')
